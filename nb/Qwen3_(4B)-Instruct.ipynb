# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth your local device, follow [our guide](https://docs.unsloth.ai/get-started/install-and-update). This notebook is licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Unsloth's [Docker image](https://hub.docker.com/r/unsloth/unsloth) is here! Start training with no setup & environment issues. [Read our Guide](https://docs.unsloth.ai/new/how-to-train-llms-with-unsloth-and-docker).
#
# [gpt-oss RL](https://docs.unsloth.ai/new/gpt-oss-reinforcement-learning) is now supported with the fastest inference & lowest VRAM. Try our [new notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/gpt-oss-(20B)-GRPO.ipynb) which creates kernels!
#
# Introducing [Vision](https://docs.unsloth.ai/new/vision-reinforcement-learning-vlm-rl) and [Standby](https://docs.unsloth.ai/basics/memory-efficient-rl) for RL! Train Qwen, Gemma etc. VLMs with GSPO - even faster with less VRAM.
#
# Unsloth now supports Text-to-Speech (TTS) models. Read our [guide here](https://docs.unsloth.ai/basics/text-to-speech-tts-fine-tuning).
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os, re
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    import torch; v = re.match(r"[0-9\.]{3,}", str(torch.__version__)).group(0)
    xformers = "xformers==" + ("0.0.32.post2" if v == "2.8.0" else "0.0.29.post3")
    # !pip install --no-deps bitsandbytes accelerate {xformers} peft trl triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" "huggingface_hub>=0.34.0" hf_transfer
    # !pip install --no-deps unsloth
# !pip install transformers==4.56.2
# !pip install --no-deps trl==0.22.2

# %% [markdown]
# ### Unsloth

# %%
from unsloth import FastLanguageModel
import torch

fourbit_models = [
    "unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit", # Qwen 14B 2x faster
    "unsloth/Qwen3-4B-Thinking-2507-unsloth-bnb-4bit",
    "unsloth/Qwen3-8B-unsloth-bnb-4bit",
    "unsloth/Qwen3-14B-unsloth-bnb-4bit",
    "unsloth/Qwen3-32B-unsloth-bnb-4bit",

    # 4bit dynamic quants for superior accuracy and low memory use
    "unsloth/gemma-3-12b-it-unsloth-bnb-4bit",
    "unsloth/Phi-4",
    "unsloth/Llama-3.1-8B",
    "unsloth/Llama-3.2-3B",
    "unsloth/orpheus-3b-0.1-ft-unsloth-bnb-4bit" # [NEW] We support TTS models!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit",
    max_seq_length = 32768, # Choose any for long context!
    load_in_4bit = True,  # 4 bit quantization to reduce memory
    load_in_8bit = False, # [NEW!] A bit more accurate, uses 2x memory
    full_finetuning = False, # [NEW!] We have full finetuning now!
    # token = "hf_...", # use one if using gated models
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.11.3: Fast Qwen3 patching. Transformers: 4.56.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update a small amount of parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 32, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 32,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.11.3 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the `Qwen-3` format for conversation style finetunes. We use [Maxime Labonne's FineTome-100k](https://huggingface.co/datasets/mlabonne/FineTome-100k) dataset in ShareGPT style. Qwen-3 renders multi turn conversations like below:
#
# ```
# <|im_start|>user
# Hello!<|im_end|>
# <|im_start|>assistant
# Hey there!<|im_end|>
#
# ```
# We use our `get_chat_template` function to get the correct chat template. We support `zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, phi3, llama3, phi4, qwen2.5, gemma3` and more.

# %%
from unsloth.chat_templates import get_chat_template
tokenizer = get_chat_template(
    tokenizer,
    chat_template = "qwen3-instruct",
)

# %%
from datasets import load_dataset
dataset = load_dataset("oxide-lab/Tauri2_Svelte5_Rust", split = "train")
# Out:
# README.md:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# dataset_final.json: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/307 [00:00<?, ? examples/s]

# %% [markdown]
# We now use `standardize_data_formats` to try converting datasets to the correct format for finetuning purposes!

# %%
from unsloth.chat_templates import standardize_data_formats
dataset = standardize_data_formats(dataset)

# %% [markdown]
# Let's see how row 100 looks like!

# %%
dataset[100]
# Out:
# {'instruction': 'Реализуй управление состоянием для компонента RadioGroup на Svelte 5, используя классы с рунами ($state, $derived). Создай корневой класс `RadioGroupRootState` и класс элемента `RadioGroupItemState`, связав их через Context API. Реализуй логику навигации с клавиатуры через `RovingFocusGroup`.',
#  'input': '',
#  'output': 'import { attachRef, type ReadableBoxedValues, type WritableBoxedValues } from "svelte-toolbelt";\nimport { Context, watch } from "runed";\nimport type {\n\tBitsFocusEvent,\n\tBitsKeyboardEvent,\n\tBitsMouseEvent,\n\tRefAttachment,\n\tWithRefOpts,\n} from "$lib/internal/types.js";\nimport {\n\tcreateBitsAttrs,\n\tgetAriaChecked,\n\tboolToEmptyStrOrUndef,\n\tboolToStr,\n} from "$lib/internal/attrs.js";\nimport type { Orientation } from "$lib/shared/index.js";\nimport { kbd } from "$lib/internal/kbd.js";\nimport { RovingFocusGroup } from "$lib/internal/roving-focus-group.js";\n\nconst radioGroupAttrs = createBitsAttrs({\n\tcomponent: "radio-group",\n\tparts: ["root", "item"],\n});\n\nconst RadioGroupRootContext = new Context<RadioGroupRootState>("RadioGroup.Root");\n\ninterface RadioGroupRootStateOpts\n\textends WithRefOpts,\n\t\tReadableBoxedValues<{\n\t\t\tdisabled: boolean;\n\t\t\trequired: boolean;\n\t\t\tloop: boolean;\n\t\t\torientation: Orientation;\n\t\t\tname: string | undefined;\n\t\t\treadonly: boolean;\n\t\t}>,\n\t\tWritableBoxedValues<{ value: string }> {}\n\nexport class RadioGroupRootState {\n\tstatic create(opts: RadioGroupRootStateOpts) {\n\t\treturn RadioGroupRootContext.set(new RadioGroupRootState(opts));\n\t}\n\n\treadonly opts: RadioGroupRootStateOpts;\n\treadonly hasValue = $derived.by(() => this.opts.value.current !== "");\n\treadonly rovingFocusGroup: RovingFocusGroup;\n\treadonly attachment: RefAttachment;\n\n\tconstructor(opts: RadioGroupRootStateOpts) {\n\t\tthis.opts = opts;\n\t\tthis.attachment = attachRef(this.opts.ref);\n\t\tthis.rovingFocusGroup = new RovingFocusGroup({\n\t\t\trootNode: this.opts.ref,\n\t\t\tcandidateAttr: radioGroupAttrs.item,\n\t\t\tloop: this.opts.loop,\n\t\t\torientation: this.opts.orientation,\n\t\t});\n\t}\n\n\tisChecked(value: string) {\n\t\treturn this.opts.value.current === value;\n\t}\n\n\tsetValue(value: string) {\n\t\tthis.opts.value.current = value;\n\t}\n\n\treadonly props = $derived.by(\n\t\t() =>\n\t\t\t({\n\t\t\t\tid: this.opts.id.current,\n\t\t\t\trole: "radiogroup",\n\t\t\t\t"aria-required": boolToStr(this.opts.required.current),\n\t\t\t\t"aria-disabled": boolToStr(this.opts.disabled.current),\n\t\t\t\t"aria-readonly": this.opts.readonly.current ? "true" : undefined,\n\t\t\t\t"data-disabled": boolToEmptyStrOrUndef(this.opts.disabled.current),\n\t\t\t\t"data-readonly": boolToEmptyStrOrUndef(this.opts.readonly.current),\n\t\t\t\t"data-orientation": this.opts.orientation.current,\n\t\t\t\t[radioGroupAttrs.root]: "",\n\t\t\t\t...this.attachment,\n\t\t\t}) as const\n\t);\n}\n\ninterface RadioGroupItemStateOpts\n\textends WithRefOpts,\n\t\tReadableBoxedValues<{\n\t\t\tdisabled: boolean;\n\t\t\tvalue: string;\n\t\t}> {}\n\nexport class RadioGroupItemState {\n\tstatic create(opts: RadioGroupItemStateOpts) {\n\t\treturn new RadioGroupItemState(opts, RadioGroupRootContext.get());\n\t}\n\n\treadonly opts: RadioGroupItemStateOpts;\n\treadonly root: RadioGroupRootState;\n\treadonly attachment: RefAttachment;\n\treadonly checked = $derived.by(() => this.root.opts.value.current === this.opts.value.current);\n\treadonly #isDisabled = $derived.by(\n\t\t() => this.opts.disabled.current || this.root.opts.disabled.current\n\t);\n\treadonly #isReadonly = $derived.by(() => this.root.opts.readonly.current);\n\treadonly #isChecked = $derived.by(() => this.root.isChecked(this.opts.value.current));\n\t#tabIndex = $state(-1);\n\n\tconstructor(opts: RadioGroupItemStateOpts, root: RadioGroupRootState) {\n\t\tthis.opts = opts;\n\t\tthis.root = root;\n\t\tthis.attachment = attachRef(this.opts.ref);\n\n\t\tif (this.opts.value.current === this.root.opts.value.current) {\n\t\t\tthis.root.rovingFocusGroup.setCurrentTabStopId(this.opts.id.current);\n\t\t\tthis.#tabIndex = 0;\n\t\t} else if (!this.root.opts.value.current) {\n\t\t\tthis.#tabIndex = 0;\n\t\t}\n\n\t\t$effect(() => {\n\t\t\tthis.#tabIndex = this.root.rovingFocusGroup.getTabIndex(this.opts.ref.current);\n\t\t});\n\n\t\twatch( ...

# %% [markdown]
# We now have to apply the chat template for `Qwen-3` onto the conversations, and save it to `text`.

# %%
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Combine instruction and input
        text = instruction + "\n" + input if input else instruction
        messages = [
            {"role": "user", "content": text},
            {"role": "assistant", "content": output}
        ]
        texts.append(tokenizer.apply_chat_template(messages, tokenize = False, add_generation_prompt = False))
    return { "text" : texts, }

dataset = dataset.map(formatting_prompts_func, batched = True)
# Out:
# Map:   0%|          | 0/307 [00:00<?, ? examples/s]

# %% [markdown]
# Let's see how the chat template did!

# %%
dataset[100]['text']
# Out:
# '<|im_start|>user\nРеализуй управление состоянием для компонента RadioGroup на Svelte 5, используя классы с рунами ($state, $derived). Создай корневой класс `RadioGroupRootState` и класс элемента `RadioGroupItemState`, связав их через Context API. Реализуй логику навигации с клавиатуры через `RovingFocusGroup`.<|im_end|>\n<|im_start|>assistant\nimport { attachRef, type ReadableBoxedValues, type WritableBoxedValues } from "svelte-toolbelt";\nimport { Context, watch } from "runed";\nimport type {\n\tBitsFocusEvent,\n\tBitsKeyboardEvent,\n\tBitsMouseEvent,\n\tRefAttachment,\n\tWithRefOpts,\n} from "$lib/internal/types.js";\nimport {\n\tcreateBitsAttrs,\n\tgetAriaChecked,\n\tboolToEmptyStrOrUndef,\n\tboolToStr,\n} from "$lib/internal/attrs.js";\nimport type { Orientation } from "$lib/shared/index.js";\nimport { kbd } from "$lib/internal/kbd.js";\nimport { RovingFocusGroup } from "$lib/internal/roving-focus-group.js";\n\nconst radioGroupAttrs = createBitsAttrs({\n\tcomponent: "radio-group",\n\tparts: ["root", "item"],\n});\n\nconst RadioGroupRootContext = new Context<RadioGroupRootState>("RadioGroup.Root");\n\ninterface RadioGroupRootStateOpts\n\textends WithRefOpts,\n\t\tReadableBoxedValues<{\n\t\t\tdisabled: boolean;\n\t\t\trequired: boolean;\n\t\t\tloop: boolean;\n\t\t\torientation: Orientation;\n\t\t\tname: string | undefined;\n\t\t\treadonly: boolean;\n\t\t}>,\n\t\tWritableBoxedValues<{ value: string }> {}\n\nexport class RadioGroupRootState {\n\tstatic create(opts: RadioGroupRootStateOpts) {\n\t\treturn RadioGroupRootContext.set(new RadioGroupRootState(opts));\n\t}\n\n\treadonly opts: RadioGroupRootStateOpts;\n\treadonly hasValue = $derived.by(() => this.opts.value.current !== "");\n\treadonly rovingFocusGroup: RovingFocusGroup;\n\treadonly attachment: RefAttachment;\n\n\tconstructor(opts: RadioGroupRootStateOpts) {\n\t\tthis.opts = opts;\n\t\tthis.attachment = attachRef(this.opts.ref);\n\t\tthis.rovingFocusGroup = new RovingFocusGroup({\n\t\t\trootNode: this.opts.ref,\n\t\t\tcandidateAttr: radioGroupAttrs.item,\n\t\t\tloop: this.opts.loop,\n\t\t\torientation: this.opts.orientation,\n\t\t});\n\t}\n\n\tisChecked(value: string) {\n\t\treturn this.opts.value.current === value;\n\t}\n\n\tsetValue(value: string) {\n\t\tthis.opts.value.current = value;\n\t}\n\n\treadonly props = $derived.by(\n\t\t() =>\n\t\t\t({\n\t\t\t\tid: this.opts.id.current,\n\t\t\t\trole: "radiogroup",\n\t\t\t\t"aria-required": boolToStr(this.opts.required.current),\n\t\t\t\t"aria-disabled": boolToStr(this.opts.disabled.current),\n\t\t\t\t"aria-readonly": this.opts.readonly.current ? "true" : undefined,\n\t\t\t\t"data-disabled": boolToEmptyStrOrUndef(this.opts.disabled.current),\n\t\t\t\t"data-readonly": boolToEmptyStrOrUndef(this.opts.readonly.current),\n\t\t\t\t"data-orientation": this.opts.orientation.current,\n\t\t\t\t[radioGroupAttrs.root]: "",\n\t\t\t\t...this.attachment,\n\t\t\t}) as const\n\t);\n}\n\ninterface RadioGroupItemStateOpts\n\textends WithRefOpts,\n\t\tReadableBoxedValues<{\n\t\t\tdisabled: boolean;\n\t\t\tvalue: string;\n\t\t}> {}\n\nexport class RadioGroupItemState {\n\tstatic create(opts: RadioGroupItemStateOpts) {\n\t\treturn new RadioGroupItemState(opts, RadioGroupRootContext.get());\n\t}\n\n\treadonly opts: RadioGroupItemStateOpts;\n\treadonly root: RadioGroupRootState;\n\treadonly attachment: RefAttachment;\n\treadonly checked = $derived.by(() => this.root.opts.value.current === this.opts.value.current);\n\treadonly #isDisabled = $derived.by(\n\t\t() => this.opts.disabled.current || this.root.opts.disabled.current\n\t);\n\treadonly #isReadonly = $derived.by(() => this.root.opts.readonly.current);\n\treadonly #isChecked = $derived.by(() => this.root.isChecked(this.opts.value.current));\n\t#tabIndex = $state(-1);\n\n\tconstructor(opts: RadioGroupItemStateOpts, root: RadioGroupRootState) {\n\t\tthis.opts = opts;\n\t\tthis.root = root;\n\t\tthis.attachment = attachRef(this.opts.ref);\n\n\t\tif (this.opts.value.current === this.root.opts.v ...

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's train our model. We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.

# %%
from trl import SFTTrainer, SFTConfig
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    eval_dataset = None, # Can set up evaluation!
    args = SFTConfig(
        dataset_text_field = "text",
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 4, # Use GA to mimic batch size!
        warmup_steps = 5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 60,
        learning_rate = 2e-4, # Reduce to 2e-5 for long training runs
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.001,
        lr_scheduler_type = "linear",
        seed = 3407,
        report_to = "none", # Use TrackIO/WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/307 [00:00<?, ? examples/s]

# %% [markdown]
# We also use Unsloth's `train_on_completions` method to only train on the assistant outputs and ignore the loss on the user's inputs. This helps increase accuracy of finetunes!

# %%
from unsloth.chat_templates import train_on_responses_only
trainer = train_on_responses_only(
    trainer,
    instruction_part = "<|im_start|>user\n",
    response_part = "<|im_start|>assistant\n",
)
# Out:
# Map (num_proc=6):   0%|          | 0/307 [00:00<?, ? examples/s]

# %% [markdown]
# Let's verify masking the instruction part is done! Let's print the 100th row again.

# %%
tokenizer.decode(trainer.train_dataset[100]["input_ids"])
# Out:
# '<|im_start|>user\nРеализуй управление состоянием для компонента RadioGroup на Svelte 5, используя классы с рунами ($state, $derived). Создай корневой класс `RadioGroupRootState` и класс элемента `RadioGroupItemState`, связав их через Context API. Реализуй логику навигации с клавиатуры через `RovingFocusGroup`.<|im_end|>\n<|im_start|>assistant\nimport { attachRef, type ReadableBoxedValues, type WritableBoxedValues } from "svelte-toolbelt";\nimport { Context, watch } from "runed";\nimport type {\n\tBitsFocusEvent,\n\tBitsKeyboardEvent,\n\tBitsMouseEvent,\n\tRefAttachment,\n\tWithRefOpts,\n} from "$lib/internal/types.js";\nimport {\n\tcreateBitsAttrs,\n\tgetAriaChecked,\n\tboolToEmptyStrOrUndef,\n\tboolToStr,\n} from "$lib/internal/attrs.js";\nimport type { Orientation } from "$lib/shared/index.js";\nimport { kbd } from "$lib/internal/kbd.js";\nimport { RovingFocusGroup } from "$lib/internal/roving-focus-group.js";\n\nconst radioGroupAttrs = createBitsAttrs({\n\tcomponent: "radio-group",\n\tparts: ["root", "item"],\n});\n\nconst RadioGroupRootContext = new Context<RadioGroupRootState>("RadioGroup.Root");\n\ninterface RadioGroupRootStateOpts\n\textends WithRefOpts,\n\t\tReadableBoxedValues<{\n\t\t\tdisabled: boolean;\n\t\t\trequired: boolean;\n\t\t\tloop: boolean;\n\t\t\torientation: Orientation;\n\t\t\tname: string | undefined;\n\t\t\treadonly: boolean;\n\t\t}>,\n\t\tWritableBoxedValues<{ value: string }> {}\n\nexport class RadioGroupRootState {\n\tstatic create(opts: RadioGroupRootStateOpts) {\n\t\treturn RadioGroupRootContext.set(new RadioGroupRootState(opts));\n\t}\n\n\treadonly opts: RadioGroupRootStateOpts;\n\treadonly hasValue = $derived.by(() => this.opts.value.current !== "");\n\treadonly rovingFocusGroup: RovingFocusGroup;\n\treadonly attachment: RefAttachment;\n\n\tconstructor(opts: RadioGroupRootStateOpts) {\n\t\tthis.opts = opts;\n\t\tthis.attachment = attachRef(this.opts.ref);\n\t\tthis.rovingFocusGroup = new RovingFocusGroup({\n\t\t\trootNode: this.opts.ref,\n\t\t\tcandidateAttr: radioGroupAttrs.item,\n\t\t\tloop: this.opts.loop,\n\t\t\torientation: this.opts.orientation,\n\t\t});\n\t}\n\n\tisChecked(value: string) {\n\t\treturn this.opts.value.current === value;\n\t}\n\n\tsetValue(value: string) {\n\t\tthis.opts.value.current = value;\n\t}\n\n\treadonly props = $derived.by(\n\t\t() =>\n\t\t\t({\n\t\t\t\tid: this.opts.id.current,\n\t\t\t\trole: "radiogroup",\n\t\t\t\t"aria-required": boolToStr(this.opts.required.current),\n\t\t\t\t"aria-disabled": boolToStr(this.opts.disabled.current),\n\t\t\t\t"aria-readonly": this.opts.readonly.current ? "true" : undefined,\n\t\t\t\t"data-disabled": boolToEmptyStrOrUndef(this.opts.disabled.current),\n\t\t\t\t"data-readonly": boolToEmptyStrOrUndef(this.opts.readonly.current),\n\t\t\t\t"data-orientation": this.opts.orientation.current,\n\t\t\t\t[radioGroupAttrs.root]: "",\n\t\t\t\t...this.attachment,\n\t\t\t}) as const\n\t);\n}\n\ninterface RadioGroupItemStateOpts\n\textends WithRefOpts,\n\t\tReadableBoxedValues<{\n\t\t\tdisabled: boolean;\n\t\t\tvalue: string;\n\t\t}> {}\n\nexport class RadioGroupItemState {\n\tstatic create(opts: RadioGroupItemStateOpts) {\n\t\treturn new RadioGroupItemState(opts, RadioGroupRootContext.get());\n\t}\n\n\treadonly opts: RadioGroupItemStateOpts;\n\treadonly root: RadioGroupRootState;\n\treadonly attachment: RefAttachment;\n\treadonly checked = $derived.by(() => this.root.opts.value.current === this.opts.value.current);\n\treadonly #isDisabled = $derived.by(\n\t\t() => this.opts.disabled.current || this.root.opts.disabled.current\n\t);\n\treadonly #isReadonly = $derived.by(() => this.root.opts.readonly.current);\n\treadonly #isChecked = $derived.by(() => this.root.isChecked(this.opts.value.current));\n\t#tabIndex = $state(-1);\n\n\tconstructor(opts: RadioGroupItemStateOpts, root: RadioGroupRootState) {\n\t\tthis.opts = opts;\n\t\tthis.root = root;\n\t\tthis.attachment = attachRef(this.opts.ref);\n\n\t\tif (this.opts.value.current === this.root.opts.v ...

# %% [markdown]
# Now let's print the masked out example - you should see only the answer is present:

# %%
tokenizer.decode([tokenizer.pad_token_id if x == -100 else x for x in trainer.train_dataset[100]["labels"]]).replace(tokenizer.pad_token, " ")
# Out:
# '                                                                                                 import { attachRef, type ReadableBoxedValues, type WritableBoxedValues } from "svelte-toolbelt";\nimport { Context, watch } from "runed";\nimport type {\n\tBitsFocusEvent,\n\tBitsKeyboardEvent,\n\tBitsMouseEvent,\n\tRefAttachment,\n\tWithRefOpts,\n} from "$lib/internal/types.js";\nimport {\n\tcreateBitsAttrs,\n\tgetAriaChecked,\n\tboolToEmptyStrOrUndef,\n\tboolToStr,\n} from "$lib/internal/attrs.js";\nimport type { Orientation } from "$lib/shared/index.js";\nimport { kbd } from "$lib/internal/kbd.js";\nimport { RovingFocusGroup } from "$lib/internal/roving-focus-group.js";\n\nconst radioGroupAttrs = createBitsAttrs({\n\tcomponent: "radio-group",\n\tparts: ["root", "item"],\n});\n\nconst RadioGroupRootContext = new Context<RadioGroupRootState>("RadioGroup.Root");\n\ninterface RadioGroupRootStateOpts\n\textends WithRefOpts,\n\t\tReadableBoxedValues<{\n\t\t\tdisabled: boolean;\n\t\t\trequired: boolean;\n\t\t\tloop: boolean;\n\t\t\torientation: Orientation;\n\t\t\tname: string | undefined;\n\t\t\treadonly: boolean;\n\t\t}>,\n\t\tWritableBoxedValues<{ value: string }> {}\n\nexport class RadioGroupRootState {\n\tstatic create(opts: RadioGroupRootStateOpts) {\n\t\treturn RadioGroupRootContext.set(new RadioGroupRootState(opts));\n\t}\n\n\treadonly opts: RadioGroupRootStateOpts;\n\treadonly hasValue = $derived.by(() => this.opts.value.current !== "");\n\treadonly rovingFocusGroup: RovingFocusGroup;\n\treadonly attachment: RefAttachment;\n\n\tconstructor(opts: RadioGroupRootStateOpts) {\n\t\tthis.opts = opts;\n\t\tthis.attachment = attachRef(this.opts.ref);\n\t\tthis.rovingFocusGroup = new RovingFocusGroup({\n\t\t\trootNode: this.opts.ref,\n\t\t\tcandidateAttr: radioGroupAttrs.item,\n\t\t\tloop: this.opts.loop,\n\t\t\torientation: this.opts.orientation,\n\t\t});\n\t}\n\n\tisChecked(value: string) {\n\t\treturn this.opts.value.current === value;\n\t}\n\n\tsetValue(value: string) {\n\t\tthis.opts.value.current = value;\n\t}\n\n\treadonly props = $derived.by(\n\t\t() =>\n\t\t\t({\n\t\t\t\tid: this.opts.id.current,\n\t\t\t\trole: "radiogroup",\n\t\t\t\t"aria-required": boolToStr(this.opts.required.current),\n\t\t\t\t"aria-disabled": boolToStr(this.opts.disabled.current),\n\t\t\t\t"aria-readonly": this.opts.readonly.current ? "true" : undefined,\n\t\t\t\t"data-disabled": boolToEmptyStrOrUndef(this.opts.disabled.current),\n\t\t\t\t"data-readonly": boolToEmptyStrOrUndef(this.opts.readonly.current),\n\t\t\t\t"data-orientation": this.opts.orientation.current,\n\t\t\t\t[radioGroupAttrs.root]: "",\n\t\t\t\t...this.attachment,\n\t\t\t}) as const\n\t);\n}\n\ninterface RadioGroupItemStateOpts\n\textends WithRefOpts,\n\t\tReadableBoxedValues<{\n\t\t\tdisabled: boolean;\n\t\t\tvalue: string;\n\t\t}> {}\n\nexport class RadioGroupItemState {\n\tstatic create(opts: RadioGroupItemStateOpts) {\n\t\treturn new RadioGroupItemState(opts, RadioGroupRootContext.get());\n\t}\n\n\treadonly opts: RadioGroupItemStateOpts;\n\treadonly root: RadioGroupRootState;\n\treadonly attachment: RefAttachment;\n\treadonly checked = $derived.by(() => this.root.opts.value.current === this.opts.value.current);\n\treadonly #isDisabled = $derived.by(\n\t\t() => this.opts.disabled.current || this.root.opts.disabled.current\n\t);\n\treadonly #isReadonly = $derived.by(() => this.root.opts.readonly.current);\n\treadonly #isChecked = $derived.by(() => this.root.isChecked(this.opts.value.current));\n\t#tabIndex = $state(-1);\n\n\tconstructor(opts: RadioGroupItemStateOpts, root: RadioGroupRootState) {\n\t\tthis.opts = opts;\n\t\tthis.root = root;\n\t\tthis.attachment = attachRef(this.opts.ref);\n\n\t\tif (this.opts.value.current === this.root.opts.value.current) {\n\t\t\tthis.root.rovingFocusGroup.setCurrentTabStopId(this.opts.id.current);\n\t\t\tthis.#tabIndex = 0;\n\t\t} else if (!this.root.opts.value.current) {\n\t\t\tthis.#tabIndex = 0;\n\t\t}\n\n\t\t$effect(() => {\n\t\t\tthis.#tabIndex = ...

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 3.816 GB of memory reserved.

# %% [markdown]
# Let's train the model! To resume a training run, set `trainer.train(resume_from_checkpoint = True)`

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 307 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 4 x 1) = 4
#  "-____-"     Trainable parameters = 66,060,288 of 4,088,528,384 (1.62% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 04:15, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.463800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.220600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.282300</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.989600</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.950300</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.249200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.882400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.017800</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.999400</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.846500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.901300</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.114200</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.760800</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.775800</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.803400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.690900</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.992700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.896100</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.879000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.148500</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.928400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.156200</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.996800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.067100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.109000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.812700</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.978300</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.863300</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.668000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.938600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.669800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.961600</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.608100</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.981400</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.690400</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.760100</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.790400</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.824900</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.772600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.989200</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.760700</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.583300</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.639600</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.033400</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.016900</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.925800</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.009800</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.184600</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.845900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.951400</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.064900</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.875900</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.761100</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.067800</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.821600</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.858100</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.009000</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.117100</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.967800</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.767900</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 279.9615 seconds used for training.
# 4.67 minutes used for training.
# Peak reserved memory = 6.062 GB.
# Peak reserved memory for training = 2.246 GB.
# Peak reserved memory % of max memory = 41.123 %.
# Peak reserved memory for training % of max memory = 15.236 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model via Unsloth native inference! According to the `Qwen-3` team, the recommended settings for instruct inference are `temperature = 0.7, top_p = 0.8, top_k = 20`
#
# For reasoning chat based inference, `temperature = 0.6, top_p = 0.95, top_k = 20`

# %%
from unsloth import FastLanguageModel
import torch

# 1. Заново загружаем модель и токенизатор
# Используйте то же имя модели, что и при старте
max_seq_length = 2048 # Или ваше значение (32k)
dtype = None
load_in_4bit = True

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "lora_model", # Загружаем вашу сохраненную локально LoRA!
    # Если локальной папки 'lora_model' уже нет (сбросилась среда),
    # загрузите базовую "unsloth/Qwen3..." и потом адаптеры,
    # или вашу модель с Hugging Face: "FerrisMind/Qwen3-LoRA"

    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)

# Включаем режим инференса для скорости
FastLanguageModel.for_inference(model)

print("✅ Модель и токенизатор восстановлены!")


messages = [
     {"role": "user", "content": "Напиши Python скрипт, который сканирует папку и находит все файлы .txt и объясни как он работает"}
]
text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)


from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors="pt").to("cuda"),
    max_new_tokens=500,
    temperature=0.1, # Ставим минимум для кода, чтобы не галлюцинировала
    streamer=TextStreamer(tokenizer, skip_prompt=True),
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-129066229.py in <cell line: 0>()
# ----> 1 from unsloth import FastLanguageModel
#       2 import torch
#       3
#       4 # 1. Заново загружаем модель и токенизатор
#       5 # Используйте то же имя модели, что и при старте
#
# /usr/local/lib/python3.12/dist-packages/unsloth/__init__.py in <module>
#     242     pass
#     243
# --> 244 from .models import *
#     245 from .models import __version__
#     246 from .save import *
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/__init__.py in <module>
#      13 # limitations under the License.
#      14
# ---> 15 from .llama import FastLlamaModel
#      16 from .loader import FastLanguageModel, FastVisionModel, FastTextModel, FastModel
#      17 from .mistral import FastMistralModel
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/llama.py in <module>
#      18 import functools
#      19 from typing import Any, Dict, Optional, Tuple, List, Union
# ---> 20 from ._utils import *
#      21 from ._utils import patch_unsloth_smart_gradient_checkpointing
#      22 from ._utils import __version__, importlib_version
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/_utils.py in <module>
#     146
#     147 for temporary_patch in TEMPORARY_PATCHES:
# --> 148     temporary_patch()
#     149
#     150 # =============================================
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/temporary_patches/gemma3n.py in patch_Gemma3nTextAltUp_functions()
#     136 def patch_Gemma3nTextAltUp_functions():
#     137     try:
# --> 138         import transformers.models.gemma3n.modeling_gemma3n
#     139         from transformers.models.gemma3n.modeling_gemma3n import Gemma3nTextAltUp
#     140     except Exception as e:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/gemma3n/modeling_gemma3n.py in <module>
#      43 from ...utils.deprecation import deprecate_kwarg
#      44 from ..auto import AutoModel
# ---> 45 from .configuration_gemma3n import Gemma3nAudioConfig, Gemma3nConfig, Gemma3nTextConfig, Gemma3nVisionConfig
#      46
#      47
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/gemma3n/configuration_gemma3n.py in <module>
#      29
#      30 if is_timm_available():
# ---> 31     from timm.data import ImageNetInfo, infer_imagenet_subset
#      32
#      33
#
# /usr/local/lib/python3.12/dist-packages/timm/__init__.py in <module>
#       6     set_exportable as set_exportable,
#       7 )
# ----> 8 from .models import (
#       9     create_model as create_model,
#      10     list_models as list_models,
#
# /usr/local/lib/python3.12/dist-packages/timm/models/__init__.py in <module>
# ----> 1 from .beit import *
#       2 from .byoanet import *
#       3 from .byobnet import *
#       4 from .cait import *
#       5 from .coat import *
#
# /usr/local/lib/python3.12/dist-packages/timm/models/beit.py in <module>
#      46 import torch.nn.functional as F
#      47
# ---> 48 from timm.data import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
#      49 from timm.layers import (
#      50     PatchEmbed,
#
# /usr/local/lib/python3.12/dist-packages/timm/data/__init__.py in <module>
#       3 from .config import resolve_data_config, resolve_model_data_config
#       4 from .constants import *
# ----> 5 from .dataset import ImageDataset, IterableImageDataset, AugMixDataset
#       6 from .dataset_factory import create_dataset
#       7 from .dataset_info import DatasetInfo, CustomDatasetInfo
#
# /usr/local/lib/python3.12/dist-packages/timm/data/dataset.py in <module>
#      11 from PIL import Image
#      12
# ---> 13 from .readers import create_reader
#      14
#      15 _logger = logging.getLogger(__name__)
#
# /usr/local/lib/python3.12/dist-packages/timm/data/readers/__init__.py in <module>
# ----> 1 from .reader_factory import create_reader
#       2 from .img_extensions import *
#
# /usr/local/lib/python3.12/dist-packages/timm/data/readers/reader_factory.py in <module>
#       2 from typing import Optional
#       3
# ----> 4 from .reader_image_folder import ReaderImageFolder
#       5 from .reader_image_in_tar import ReaderImageInTar
#       6
#
# /usr/local/lib/python3.12/dist-packages/timm/data/readers/reader_image_folder.py in <module>
#       9 from typing import Dict, List, Optional, Set, Tuple, Union
#      10
# ---> 11 from timm.utils.misc import natural_key
#      12
#      13 from .class_map import load_class_map
#
# /usr/local/lib/python3.12/dist-packages/timm/utils/__init__.py in <module>
#      14 from .model_ema import ModelEma, ModelEmaV2, ModelEmaV3
#      15 from .random import random_seed
# ---> 16 from .summary import update_summary, get_outdir
#
# /usr/local/lib/python3.12/dist-packages/timm/utils/summary.py in <module>
#       7 from collections import OrderedDict
#       8 try:
# ----> 9     import wandb
#      10 except ImportError:
#      11     pass
#
# /usr/local/lib/python3.12/dist-packages/wandb/__init__.py in <module>
#      20
#      21 # Configure the logger as early as possible for consistent behavior.
# ---> 22 from wandb.sdk.lib import wb_logging as _wb_logging
#      23 _wb_logging.configure_wandb_logger()
#      24
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/__init__.py in <module>
#      23
#      24 from . import wandb_helper as helper
# ---> 25 from .artifacts.artifact import Artifact
#      26 from .wandb_alerts import AlertLevel
#      27 from .wandb_config import Config
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/artifacts/artifact.py in <module>
#      28
#      29 import wandb
# ---> 30 from wandb import data_types, env
#      31 from wandb._iterutils import one, unique_list
#      32 from wandb._pydantic import from_json
#
# /usr/local/lib/python3.12/dist-packages/wandb/data_types.py in <module>
#      14 """
#      15
# ---> 16 from .sdk.data_types.audio import Audio
#      17 from .sdk.data_types.base_types.media import BatchableMedia, Media
#      18 from .sdk.data_types.base_types.wb_value import WBValue
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/data_types/audio.py in <module>
#       9 from . import _dtypes
#      10 from ._private import MEDIA_TMP
# ---> 11 from .base_types.media import BatchableMedia
#      12
#      13 if TYPE_CHECKING:
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/data_types/base_types/media.py in <module>
#      11 from wandb.sdk.lib.paths import LogicalPath
#      12
# ---> 13 from .wb_value import WBValue
#      14
#      15 if TYPE_CHECKING:  # pragma: no cover
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/data_types/base_types/wb_value.py in <module>
#       2
#       3 from wandb import util
# ----> 4 from wandb.sdk import wandb_setup
#       5
#       6 if TYPE_CHECKING:  # pragma: no cover
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/wandb_setup.py in <module>
#      37 from wandb.sdk.lib import asyncio_manager, import_hooks, wb_logging
#      38
# ---> 39 from . import wandb_settings
#      40 from .lib import config_util, server
#      41
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/wandb_settings.py in <module>
#      36 from wandb.proto import wandb_settings_pb2
#      37
# ---> 38 from .lib import apikey, credentials, ipython
#      39 from .lib.gitlib import GitRepo
#      40 from .lib.run_moment import RunMoment
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/lib/apikey.py in <module>
#      19
#      20 import wandb
# ---> 21 from wandb.apis import InternalApi
#      22 from wandb.errors import term
#      23 from wandb.errors.links import url_registry
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/__init__.py in <module>
#      44
#      45 from .internal import Api as InternalApi  # noqa
# ---> 46 from .public import Api as PublicApi  # noqa
#      47
#      48 reset_path()
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/public/__init__.py in <module>
#      42
#      43
# ---> 44 from wandb.apis.public.api import Api, RetryingClient, requests
#      45 from wandb.apis.public.artifacts import (
#      46     ArtifactCollection,
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/public/api.py in <module>
#      35 from wandb.apis.normalize import normalize_exceptions
#      36 from wandb.apis.public.const import RETRY_TIMEDELTA
# ---> 37 from wandb.apis.public.registries import Registries, Registry
#      38 from wandb.apis.public.registries._utils import fetch_org_entity_from_organization
#      39 from wandb.apis.public.utils import (
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/public/registries/__init__.py in <module>
#       4 ]
#       5
# ----> 6 from .registries_search import Registries
#       7 from .registry import Registry
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/public/registries/registries_search.py in <module>
#      12 from wandb._analytics import tracked
#      13 from wandb.apis.paginator import Paginator
# ---> 14 from wandb.apis.public.artifacts import ArtifactCollection
#      15 from wandb.apis.public.utils import gql_compat
#      16 from wandb.sdk.artifacts._generated import (
#
# /usr/local/lib/python3.12/dist-packages/wandb/apis/public/artifacts.py in <module>
#      69 from wandb.sdk.artifacts._gqlutils import omit_artifact_fields
#      70 from wandb.sdk.artifacts._models import ArtifactCollectionData
# ---> 71 from wandb.sdk.artifacts._models.pagination import (
#      72     ArtifactCollectionConnection,
#      73     ArtifactFileConnection,
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/artifacts/_models/pagination.py in <module>
#      16 ArtifactTypeConnection = Connection[ArtifactTypeFragment]
#      17 ArtifactCollectionConnection = ConnectionWithTotal[ArtifactCollectionFragment]
# ---> 18 ArtifactMembershipConnection = Connection[ArtifactMembershipFragment]
#      19
#      20 FileWithUrlConnection = Connection[FileWithUrlFragment]
#
# /usr/local/lib/python3.12/dist-packages/pydantic/main.py in __class_getitem__(cls, typevar_values)
#     909                     pass
#     910
# --> 911                 submodel = _generics.create_generic_submodel(model_name, origin, args, params)
#     912
#     913                 _generics.set_cached_generic_type(cls, typevar_values, submodel, origin, args)
#
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generics.py in create_generic_submodel(model_name, origin, args, params)
#     126     meta, ns, kwds = prepare_class(model_name, bases)
#     127     namespace.update(ns)
# --> 128     created_model = meta(
#     129         model_name,
#     130         bases,
#
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_model_construction.py in __new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     219             ns_resolver = NsResolver(parent_namespace=parent_namespace)
#     220
# --> 221             set_model_fields(cls, config_wrapper=config_wrapper, ns_resolver=ns_resolver)
#     222
#     223             # This is also set in `complete_model_class()`, after schema gen because they are recreated.
#
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_model_construction.py in set_model_fields(cls, config_wrapper, ns_resolver)
#     542     """
#     543     typevars_map = get_model_typevars_map(cls)
# --> 544     fields, class_vars = collect_model_fields(cls, config_wrapper, ns_resolver, typevars_map=typevars_map)
#     545
#     546     cls.__pydantic_fields__ = fields
#
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_fields.py in collect_model_fields(cls, config_wrapper, ns_resolver, typevars_map)
#     279
#     280     if config_wrapper.use_attribute_docstrings:
# --> 281         _update_fields_from_docstrings(cls, fields)
#     282     return fields, class_vars
#     283
#
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_fields.py in _update_fields_from_docstrings(cls, fields, use_inspect)
#      70
#      71 def _update_fields_from_docstrings(cls: type[Any], fields: dict[str, FieldInfo], use_inspect: bool = False) -> None:
# ---> 72     fields_docs = extract_docstrings_from_cls(cls, use_inspect=use_inspect)
#      73     for ann_name, field_info in fields.items():
#      74         if field_info.description is None and ann_name in fields_docs:
#
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_docs_extraction.py in extract_docstrings_from_cls(cls, use_inspect)
#      97             return {}
#      98     else:
# ---> 99         source = _extract_source_from_frame(cls)
#     100
#     101     if not source:
#
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_docs_extraction.py in _extract_source_from_frame(cls)
#      53
#      54     while frame:
# ---> 55         if inspect.getmodule(frame) is inspect.getmodule(cls):
#      56             lnum = frame.f_lineno
#      57             try:
#
# /usr/lib/python3.12/inspect.py in getmodule(object, _filename)
#     997     # Try the cache again with the absolute file name
#     998     try:
# --> 999         file = getabsfile(object, _filename)
#    1000     except (TypeError, FileNotFoundError):
#    1001         return None
#
# /usr/lib/python3.12/inspect.py in getabsfile(object, _filename)
#     980     normalizes the result as much as possible."""
#     981     if _filename is None:
# --> 982         _filename = getsourcefile(object) or getfile(object)
#     983     return os.path.normcase(os.path.abspath(_filename))
#     984
#
# /usr/lib/python3.12/inspect.py in getsourcefile(object)
#     968         return filename
#     969     # only return a non-existent filename if the module has a PEP 302 loader
# --> 970     module = getmodule(object, filename)
#     971     if getattr(module, '__loader__', None) is not None:
#     972         return filename
#
# /usr/lib/python3.12/inspect.py in getmodule(object, _filename)
#    1005     # Copy sys.modules in order to cope with changes while iterating
#    1006     for modname, module in sys.modules.copy().items():
# -> 1007         if ismodule(module) and hasattr(module, '__file__'):
#    1008             f = module.__file__
#    1009             if f == _filesbymodname.get(modname, None):
#
# KeyboardInterrupt:

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/chat_template.jinja',
#  'lora_model/vocab.json',
#  'lora_model/merges.txt',
#  'lora_model/added_tokens.json',
#  'lora_model/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = 2048,
        load_in_4bit = True,
    )

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
if True:
    model.save_pretrained_merged("Qwen3-4B-Ruster-16bit", tokenizer, save_method = "merged_16bit",)

# Merge to 4bit
if True:
    model.save_pretrained_merged("Qwen3-4B-Ruster-4bit", tokenizer, save_method = "merged_4bit_forced",)
# Out:
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# Checking cache directory for required files...
# Cache check failed: model-00001-of-00002.safetensors not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Checking cache directory for required files...
# Cache check failed: tokenizer.model not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Unsloth: Preparing safetensor model files: 100%|██████████| 2/2 [00:00<00:00, 14266.34it/s]
# Note: tokenizer.model not found (this is OK for non-SentencePiece models)
# Unsloth: Merging weights into 16bit:   0%|          | 0/2 [01:59<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-755274728.py in <cell line: 0>()
#       1 if True:
# ----> 2     model.save_pretrained_merged("Qwen3-4B-Ruster-16bit", tokenizer, save_method = "merged_16bit",)
#       3
#       4 # Merge to 4bit
#       5 if True:
#
# /usr/local/lib/python3.12/dist-packages/unsloth/save.py in unsloth_generic_save_pretrained_merged(self, save_directory, tokenizer, save_method, push_to_hub, token, is_main_process, state_dict, save_function, max_shard_size, safe_serialization, variant, save_peft_format, tags, temporary_location, maximum_memory_usage)
#    2686     arguments["model"] = self
#    2687     del arguments["self"]
# -> 2688     unsloth_generic_save(**arguments)
#    2689     for _ in range(3):
#    2690         gc.collect()
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/unsloth/save.py in unsloth_generic_save(model, tokenizer, save_directory, save_method, push_to_hub, token, is_main_process, state_dict, save_function, max_shard_size, safe_serialization, variant, save_peft_format, use_temp_dir, commit_message, private, create_pr, revision, commit_description, tags, temporary_location, maximum_memory_usage)
#    2634         save_method = "merged_4bit"
#    2635
# -> 2636     merge_and_overwrite_lora(
#    2637         get_model_name,
#    2638         model = model,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/saving_utils.py in merge_and_overwrite_lora(get_model_name, model, tokenizer, save_directory, push_to_hub, private, token, save_method, output_dtype, low_disk_space_usage, use_temp_file, cleanup_temp_file)
#    1315
#    1316     for filename in ProgressBar(final_safetensors_list, desc=f'Unsloth: Merging weights into {"mxfp4" if save_method=="mxfp4" else "16bit"}'):
# -> 1317         n_saved_modules += _merge_and_overwrite_lora(
#    1318             save_directory = save_directory,
#    1319             filename = filename,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/saving_utils.py in _merge_and_overwrite_lora(save_directory, filename, lora_weights, output_dtype, model_class_name, base_model_is_quantized, quant_type, save_method)
#     499
#     500                 del W
# --> 501                 torch.cuda.empty_cache()
#     502             pass
#     503             # Success! Direct overwrite completed
#
# /usr/local/lib/python3.12/dist-packages/torch/cuda/memory.py in empty_cache()
#     210
#     211
# --> 212 def empty_cache() -> None:
#     213     r"""Release all unoccupied cached memory currently held by the caching
#     214     allocator so that those can be used in other GPU application and visible in
#
# KeyboardInterrupt:

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)

# %% [markdown]
# Likewise, if you want to instead push to GGUF to your Hugging Face account, set `if False` to `if True` and add your Hugging Face token and upload location!

# %%
# Save to 8bit Q8_0
if True:
    model.save_pretrained_gguf("Qwen3-4B-Ruster-Q8_0", tokenizer, quantization_method = "q8_0")
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False:
    model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False:
    model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: # Pushing to HF Hub
    model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if True:
    model.save_pretrained_gguf("Qwen3-4B-Ruster-Q5_K_M", tokenizer, quantization_method = "q5_k_m")
if False: # Pushing to HF Hub
    model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "", # Get a token at https://huggingface.co/settings/tokens
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp.
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
#
#   This notebook and all Unsloth notebooks are licensed [LGPL-3.0](https://github.com/unslothai/notebooks?tab=LGPL-3.0-1-ov-file#readme).
